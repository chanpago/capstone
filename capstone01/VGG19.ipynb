# %%
from keras.applications.vgg19 import VGG19
from keras import layers, models
from keras.models import Model
from keras.layers import GlobalAveragePooling2D, Dense
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import adam_v2
import os
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

os.environ["CUDA_VISIBLE_DEVICES"] = "1,2,3,4,5"

def eachFile(filepath):
	pathDir = os.listdir(filepath)
	out = []
	for allDir in pathDir:
		child = allDir
		out.append(child)
	return out


NUM_CLASSES = 11
TRAIN_PATH = '/Volumes/T7/CCTV_data/Training'
#TRAIN_PATH = '/Volumes/T7/validation/Validation'
VALID_PATH = 'dataset/train'
FC_NUMS = 4096

FREEZE_LAYERS = 17

IMAGE_SIZE = 224

base_model = VGG19(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, weights='imagenet')
base_model.trainable = False
additional_model = models.Sequential()
additional_model.add(base_model)
additional_model.add(layers.Flatten())
additional_model.add(layers.Dense(4096, activation='relu'))
additional_model.add(layers.Dense(2048, activation='relu'))
additional_model.add(layers.Dense(1024, activation='relu'))
additional_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

additional_model.summary()
    
additional_model.compile(optimizer=adam_v2.Adam(lr=2e-5), loss='categorical_crossentropy', metrics=['accuracy'])
train_datagen = ImageDataGenerator(    
    rescale = 1. /255.,
    validation_split=0.2,
)
train_generator = train_datagen.flow_from_directory(directory=TRAIN_PATH,
                                                    target_size=(IMAGE_SIZE, IMAGE_SIZE), classes=eachFile(TRAIN_PATH), subset='training')
test_generator = train_datagen.flow_from_directory(directory=TRAIN_PATH,
                                                    target_size=(IMAGE_SIZE, IMAGE_SIZE), classes=eachFile(TRAIN_PATH), subset='validation')
print(test_generator.class_indices)
filepath = 'model/sewer_weight.h5'
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')

history_ft = additional_model.fit_generator(train_generator, epochs=20, callbacks=[checkpoint], 
                                 validation_data=test_generator, validation_steps=5)
additional_model.save('model/sewer_weight_final.h5')

# %%
from keras.utils.generic_utils import CustomObjectScope
from tensorflow.python.keras.initializers import glorot_uniform
from keras.layers import GlobalAveragePooling2D, Dense 
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1,2,3"

print("-- Evaluate --")
#valid_dir = '/Volumes/T7/validation/Validation'
#valid_dir = 'dataset/Testing'
#valid_dir = '/Volumes/T7/CCTV_data/Testing'
valid_dir = 'dataset/train'
model_path = 'model_test/sewer_weight.h5'
with CustomObjectScope({'GlorotUniform': glorot_uniform()}):
        model = load_model(model_path)

IMAGE_SIZE = 224

def eachFile(filepath):
     pathDir = os.listdir(filepath)
     out = []
     for allDir in pathDir:
             child = allDir
             out.append(child)
     return out

valid_datagen = ImageDataGenerator(rescale = 1./255)


# 'valid_dir' 디렉토리에 저장된 이미지 전처리
valid_generator = valid_datagen.flow_from_directory(valid_dir, target_size=(IMAGE_SIZE, IMAGE_SIZE), class_mode='categorical',shuffle=False)
print(valid_generator.class_indices)
scores = model.evaluate_generator(valid_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# -- Evaluate --
# Found 550 images belonging to 11 classes.
# {'SD': 0, 'UD_IN': 1, 'BK': 2, 'DS': 3, 'JF': 4, 'LP': 5, 'UD_PJ': 6, 'ETC': 7, 'CC': 8, 'JD': 9, 'CL': 10}
# 2022-05-27 15:16:35.357750: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# accuracy: 7.50%

# %%
import numpy as np

test_dir = 'dataset/train'
test_datagen = ImageDataGenerator(rescale = 1./255)
model_path = 'model_test/sewer_weight.h5'
with CustomObjectScope({'GlorotUniform': glorot_uniform()}):
        model = load_model(model_path)

# 'valid_dir' 디렉토리에 저장된 이미지 전처리
test_generator = test_datagen.flow_from_directory(test_dir, target_size=(IMAGE_SIZE, IMAGE_SIZE), class_mode='categorical', shuffle=False)
test_generator.reset()
output = model.predict_generator(test_generator, steps=5)

test_file_names=test_generator.filenames  
test_labels=test_generator.labels 
class_dict= test_generator.class_indices
print (class_dict) 
new_dict={} 
for key in class_dict: 
    value=class_dict[key]
    new_dict[value]=key
print('PREDICTED CLASS      TRUE CLASS          FILENAME ' )
for i, p in enumerate(output):
    pred_index=np.argmax(p)
    pred_class=new_dict[pred_index] 
    true_class=new_dict[test_labels[i]]
    file=test_file_names[i]
    print(f'       {pred_class}           {true_class}            {file}')
# Out:
# Found 550 images belonging to 11 classes.
# 2022-05-27 15:13:19.689925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# {'BK': 0, 'CC': 1, 'CL': 2, 'DS': 3, 'ETC': 4, 'JD': 5, 'JF': 6, 'LP': 7, 'SD': 8, 'UD_IN': 9, 'UD_PJ': 10}
# PREDICTED CLASS      TRUE CLASS          FILENAME
#        BK           BK            BK/BK_039931.png
#        BK           BK            BK/BK_039932.png
#        JF           BK            BK/BK_039933.png
#        BK           BK            BK/BK_039934.png
#        BK           BK            BK/BK_039935.png
#        BK           BK            BK/BK_039936.png
#        SD           BK            BK/BK_039937.png
#        BK           BK            BK/BK_039938.png
#        BK           BK            BK/BK_039939.png
#        BK           BK            BK/BK_039940.png
#        BK           BK            BK/BK_039941.png
#        BK           BK            BK/BK_039942.png
#        BK           BK            BK/BK_039943.png
#        JF           BK            BK/BK_039944.png
#        BK           BK            BK/BK_039945.png
#        BK           BK            BK/BK_039946.png
#        BK           BK            BK/BK_039947.png
#        BK           BK            BK/BK_039948.png
#        BK           BK            BK/BK_039949.png
#        BK           BK            BK/BK_039950.png
#        BK           BK            BK/BK_039951.png
#        BK           BK            BK/BK_039952.png
#        BK           BK            BK/BK_039953.png
#        BK           BK            BK/BK_039954.png
#        JF           BK            BK/BK_039955.png
#        BK           BK            BK/BK_039956.png
#        BK           BK            BK/BK_039957.png
#        BK           BK            BK/BK_039958.png
#        BK           BK            BK/BK_039959.png
#        BK           BK            BK/BK_039960.png
#        LP           BK            BK/BK_039961.png
#        BK           BK            BK/BK_039962.png
#        BK           BK            BK/BK_039963.png
#        BK           BK            BK/BK_039964.png
#        LP           BK            BK/BK_039965.png
#        BK           BK            BK/BK_039966.png
#        BK           BK            BK/BK_039967.png
#        BK           BK            BK/BK_039968.png
#        BK           BK            BK/BK_039969.png
#        BK           BK            BK/BK_039970.png
#        LP           BK            BK/BK_039971.png
#        ETC           BK            BK/BK_039972.png
#        BK           BK            BK/BK_039973.png
#        LP           BK            BK/BK_039974.png
#        BK           BK            BK/BK_039975.png
#        BK           BK            BK/BK_039976.png
#        SD           BK            BK/BK_039977.png
#        LP           BK            BK/BK_039978.png
#        BK           BK            BK/BK_039999.png
#        BK           BK            BK/BK_040000.png
#        CC           CC            CC/CC_019946.png
#        CC           CC            CC/CC_019947.png
#        CC           CC            CC/CC_019948.png
#        CC           CC            CC/CC_019949.png
#        CC           CC            CC/CC_019950.png
#        ETC           CC            CC/CC_019956.png
#        CC           CC            CC/CC_019957.png
#        CC           CC            CC/CC_019958.png
#        CC           CC            CC/CC_019959.png
#        CC           CC            CC/CC_019960.png
#        CC           CC            CC/CC_019961.png
#        CC           CC            CC/CC_019962.png
#        CC           CC            CC/CC_019963.png
#        CC           CC            CC/CC_019964.png
#        CC           CC            CC/CC_019965.png
#        CC           CC            CC/CC_019966.png
#        CC           CC            CC/CC_019967.png
#        CC           CC            CC/CC_019968.png
#        CC           CC            CC/CC_019969.png
#        CC           CC            CC/CC_019970.png
#        CC           CC            CC/CC_019971.png
#        CC           CC            CC/CC_019972.png
#        CC           CC            CC/CC_019973.png
#        ETC           CC            CC/CC_019974.png
#        CC           CC            CC/CC_019975.png
#        CC           CC            CC/CC_019976.png
#        CC           CC            CC/CC_019977.png
#        CC           CC            CC/CC_019978.png
#        ETC           CC            CC/CC_019979.png
#        CC           CC            CC/CC_019980.png
#        CC           CC            CC/CC_019981.png
#        CC           CC            CC/CC_019982.png
#        CC           CC            CC/CC_019983.png
#        CC           CC            CC/CC_019984.png
#        CC           CC            CC/CC_019985.png
#        CC           CC            CC/CC_019986.png
#        CC           CC            CC/CC_019987.png
#        CC           CC            CC/CC_019988.png
#        CL           CC            CC/CC_019989.png
#        CC           CC            CC/CC_019990.png
#        CC           CC            CC/CC_019991.png
#        CC           CC            CC/CC_019992.png
#        CC           CC            CC/CC_019993.png
#        CC           CC            CC/CC_019994.png
#        ETC           CC            CC/CC_019995.png
#        CC           CC            CC/CC_019996.png
#        CC           CC            CC/CC_019997.png
#        ETC           CC            CC/CC_019998.png
#        CC           CC            CC/CC_019999.png
#        ETC           CC            CC/CC_020000.png
#        CL           CL            CL/CL_019951.png
#        CL           CL            CL/CL_019952.png
#        CL           CL            CL/CL_019953.png
#        CL           CL            CL/CL_019954.png
#        BK           CL            CL/CL_019955.png
#        BK           CL            CL/CL_019956.png
#        CL           CL            CL/CL_019957.png
#        CL           CL            CL/CL_019958.png
#        CL           CL            CL/CL_019959.png
#        CL           CL            CL/CL_019960.png
#        CL           CL            CL/CL_019961.png
#        CL           CL            CL/CL_019962.png
#        ETC           CL            CL/CL_019963.png
#        CL           CL            CL/CL_019964.png
#        CL           CL            CL/CL_019965.png
#        CL           CL            CL/CL_019966.png
#        CL           CL            CL/CL_019967.png
#        CL           CL            CL/CL_019968.png
#        CL           CL            CL/CL_019969.png
#        CL           CL            CL/CL_019970.png
#        CL           CL            CL/CL_019971.png
#        BK           CL            CL/CL_019972.png
#        CL           CL            CL/CL_019973.png
#        CL           CL            CL/CL_019974.png
#        CL           CL            CL/CL_019975.png
#        CL           CL            CL/CL_019976.png
#        CL           CL            CL/CL_019977.png
#        CL           CL            CL/CL_019978.png
#        CL           CL            CL/CL_019979.png
#        CL           CL            CL/CL_019980.png
#        CL           CL            CL/CL_019981.png
#        CL           CL            CL/CL_019982.png
#        CL           CL            CL/CL_019983.png
#        CL           CL            CL/CL_019984.png
#        CL           CL            CL/CL_019985.png
#        CL           CL            CL/CL_019986.png
#        CL           CL            CL/CL_019987.png
#        CL           CL            CL/CL_019988.png
#        CL           CL            CL/CL_019989.png
#        CL           CL            CL/CL_019990.png
#        CL           CL            CL/CL_019991.png
#        CL           CL            CL/CL_019992.png
#        CL           CL            CL/CL_019993.png
#        CL           CL            CL/CL_019994.png
#        CL           CL            CL/CL_019995.png
#        CL           CL            CL/CL_019996.png
#        CL           CL            CL/CL_019997.png
#        CL           CL            CL/CL_019998.png
#        CL           CL            CL/CL_019999.png
#        CL           CL            CL/CL_020000.png
#        DS           DS            DS/DS_029946.png
#        DS           DS            DS/DS_029947.png
#        DS           DS            DS/DS_029948.png
#        LP           DS            DS/DS_029949.png
#        DS           DS            DS/DS_029950.png
#        ETC           DS            DS/DS_029956.png
#        ETC           DS            DS/DS_029957.png
#        DS           DS            DS/DS_029958.png
#        DS           DS            DS/DS_029959.png
#        DS           DS            DS/DS_029960.png

# %%
import PIL
from pathlib import Path
from PIL import UnidentifiedImageError
from PIL import Image
import os

#folder_path = '/Volumes/T7/CCTV_data/Training/DS'
#folder_path = 'dataset/train/'

folder_path = '/Volumes/T7/validation/Validation/UD_PJ'
print(len(os.listdir(folder_path)))
path = Path(folder_path).rglob("*.png")
for img_p in path:
    try:
        img = PIL.Image.open(img_p)
    except PIL.UnidentifiedImageError:
            print(img_p)
